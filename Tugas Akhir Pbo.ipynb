# %% [markdown]
# # PYGAME
# ![](./gambar/destop%20pygame.png)
# =>pygame adalah seperangkat modul Python yang dirancang untuk membuat permainan. Pygame menambahkan fungsi di atas dengan sangat baik di SDL perpustakaan. Hal ini memungkinkan Anda untuk membuat sebuah game dengan fitur yang lengkap dan sebuah program multimedia dalam bahasa python. Pygame sangat portabel dan dapat berjalan pada hampir semua platform dan sistem operasi. Pygame sendiri telah didownload jutaan kali, dan telah memiliki jutaan kunjungan ke situsnya.
# Pygame ini gratis. Dan dirilis di bawah Lisensi GPL , Anda dapat membuat sebuah aplikasi yang open source, gratis, freeware, shareware, dan game komersial dengan pygame ini.
#
# Untuk pengenalan yang bagus untuk pygame ini, periksa baris demi baris simpanse tutorial , dan pengenalan untuk programmer python atau Bab 17 sampai 20 dari buku "Ciptakan Anda Game Komputer Sendiri dengan Python" .
#
# PyGame dapat kita install menggunakan pip dengan perintah berikut:
# 1.Install PIP lewwat command prom
#  dengan mengetikkan "sudo pip install pygame"
#  nah kalau sudah selesai tinggal kita cek buka lewat python dengan cara
#  import pygame kalau proses running berhasil jadi pygame siap dijalankan
#
#  berikut script pygame nya:
# ![](./gambar/pygame1.PNG)
# ![](./gambar/pygame2.PNG)
# ![](./gambar/pygame3.PNG)
# ![](./gambar/pygame4.PNG)
# ![](./gambar/pygame5.PNG)
# ![](./gambar/pygame6.PNG)
#
# Dan Ini hasil runningnya:
# ![](./gambar/run%20pygame.PNG)

# %% [markdown]
# # Penjelasan Setiap Class
# 1.class Bird(pygame.sprite.Sprite):
#   ![](./gambar/class%20pygame%201.PNG)
# 2.![](./gambar/class%20pygame%202.PNG)
# 3.![](./gambar/class%20pygame%203.PNG)
# 4.![](./gambar/class%20pygame%204.PNG)

# %% [markdown]
# # Implementasi Class di  OPP
#
# Di dalam game tersebut Terdapat konsep OOP yakni Inheritance.
# Inheritance Superclass:Menunjukkan class yang berarti parent class dari subclass/class anak
# berikut contoh source code:![](./gambar/pygame%20inheritance.PNG)

# %% [markdown]
# # Kivy
# ![](./gambar/logo%20kivy.png)
# kivy adalah modul atau pustaka open source pada Python yang digunakan untuk membuat atau mengembangkan aplikasi seluler.
#
# Kivy dapat berjalan di Windows, OS X, Android, iOS, dan Raspberry Pi. Kita juga dapat menjalankan kode yang sama pada semua platform yang berbeda pula.

# %% [markdown]
# # Script Code Aplikasi Kivy
# ![](./gambar/kivy1.PNG)
# ![](./gambar/kivy2.PNG)
# hasil screenshot program aplikasi Kivy
# ![](./gambar/run%20kiky.PNG)

# %% [markdown]
# # Instalation Kivy
# 1.Buka CMD lalu Pada tampilan cmd silahkan anda ketik perintah dibawah ini lalu tekan enter"python -m pip install --upgrade pip wheel setuptools"
# 2.Jika langkah pertama sudah selesai ketik perintah berikut pada cmd pula, tunggu hingga proses selesai"python -m pip install docutils pygments pypiwin32 kivy.deps.sdl2 kivy.deps.glew"
# 3.Sama seperti sebelumya ketik "python -m pip install kivy.deps.gstreamer --extra-index-url
# 4.Langkah terakhir ketik"python -m pip install kivy"
# 5.Lalu cek di CMD dengan Mengetik "import KIVY"

# %% [markdown]
# # Penjelasan Setiap Class

# %% [markdown]
# # Implementasi Materi OOP di Kivy
#
# di dalam Aplikasi  tersebut Terdapat konsep OOP yakni Inheritance yang paling banyak terlihat.
# Inheritance Superclass:Menunjukkan class yang berarti parent class dari subclass/class anak
# berikut contoh source code:![](./gambar/class%20kivy1.PNG)
# ![](./gambar/class%20kivy2.PNG)
